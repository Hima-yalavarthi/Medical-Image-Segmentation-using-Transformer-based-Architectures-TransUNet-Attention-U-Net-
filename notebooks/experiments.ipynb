# %% [markdown]
# # Medical Image Segmentation Experiments
# This notebook provides a simple interface to run experiments and visualize results.

# %%
import torch
from training.train import main as train_model
from evaluation.evaluate import compare_models

# 1. Run Training for Attention U-Net
# train_model(model_name='attention_unet', epochs=5)

# 2. Run Training for TransUNet
# train_model(model_name='transunet', epochs=5)

# 3. Compare Models
# compare_models()
